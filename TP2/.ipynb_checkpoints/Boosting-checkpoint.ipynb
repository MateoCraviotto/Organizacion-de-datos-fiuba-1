# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score

# %%
from preprocessing import dividir_dataset
from preprocessing import preparar_dataset

# %%
from funcionesAuxiliares import graficar_auc_roc
from funcionesAuxiliares import traer_df

# %%
df = traer_df()
df = preparar_dataset(df)

# %%
X, y = dividir_dataset(df)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
def definir_mejores_hiperparametros_no_va(X, y):    
    metrics = []
    y_array = np.array(y)
    for funcion_perdida in ['deviance', 'exponential']:
        for estimadores in [10, 50, 100, 150, 200]:
            for learning_rate in [0.001, 0.01, 0.1]:
                for criterio in ['friedman_mse', 'mse']:
                    kf = StratifiedKFold(n_splits=5)
                    metricas_de_la_combinacion = []
                    for fold_index, (train_index, test_index) in enumerate(kf.split(X, y_array)):
                        train_fold_actual = X.iloc[train_index].copy()
                        test_fold_actual = X.iloc[test_index].copy()
                        train_fold_actual, test_fold_actual = normalizar_datos(train_fold_actual, test_fold_actual)
                        boosting = GradientBoostingClassifier(loss = funcion_perdida, n_estimators = estimadores, learning_rate = learning_rate, criterion = criterio)
                        boosting.fit(train_fold_actual, y.iloc[train_index])
                        y_pred = boosting.predict(test_fold_actual)
                        metricas_de_la_combinacion.append(roc_auc_score(y.iloc[test_index], y_pred))
                        print(roc_auc_score(y.iloc[test_index], y_pred))
                    print(f"Promedio de la combinación: {np.mean(metricas_de_la_combinacion)}")
                    metrics.append((funcion_perdida, estimadores, learning_rate, criterio, np.mean(metricas_de_la_combinacion)))
                    print("Terminé fold")
                
    df_metrics = pd.DataFrame(metrics, columns=['funcion_perdida','estimadores','learning_rate', 'criterio', 'rocauc'])
    mejor_combinacion = df_metrics[df_metrics["rocauc"] ==  max(df_metrics.rocauc)]   
    return mejor_combinacion

# %%
def definir_mejores_hiperparametros(X, y):    
    metrics = []
    y_array=np.array(y)
    for funcion_perdida in ['deviance', 'exponential']:
        for estimadores in [1, 10, 20, 50, 100, 150, 200]:
            for learning_rate in [0.001, 0.01, 0.1]:
                for criterio in ['friedman_mse', 'mse']:
                    kf = StratifiedKFold(n_splits=5)
                    metricas_de_la_combinacion = []
                    for fold_index, (train_index, test_index) in enumerate(kf.split(X, y_array)):
                        boosting = GradientBoostingClassifier(loss = funcion_perdida, n_estimators = estimadores, learning_rate = learning_rate, criterion = criterio)
                        boosting.fit(X.iloc[train_index], y.iloc[train_index])
                        y_pred = boosting.predict(X.iloc[test_index])
                        metricas_de_la_combinacion.append(roc_auc_score(y.iloc[test_index], y_pred))
                        print(roc_auc_score(y.iloc[test_index], y_pred))
                    print(f"Promedio de la combinación: {np.mean(metricas_de_la_combinacion)}")
                    metrics.append((funcion_perdida, estimadores, learning_rate, criterio, np.mean(metricas_de_la_combinacion)))
                    print("Terminé fold")
                
    df_metrics = pd.DataFrame(metrics, columns=['funcion_perdida','estimadores','learning_rate', 'criterio', 'rocauc'])
    mejor_combinacion = df_metrics[df_metrics["rocauc"] ==  max(df_metrics.rocauc)]   
    return mejor_combinacion

# %%
mejor_combinacion = definir_mejores_hiperparametros(X, y)
print(mejor_combinacion)
# Out:
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.7041238544741256
# 0.7088998827686414
# 0.7197953817449311
# 0.7186055247341655
# 0.7121505762499174
# Promedio de la combinación: 0.7127150439943561
# Terminé fold
# 0.7041238544741256
# 0.7088998827686414
# 0.7197953817449311
# 0.7186055247341655
# 0.7121505762499174
# Promedio de la combinación: 0.7127150439943561
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.7507993929718392
# 0.7495975331880326
# 0.7600812776566938
# 0.7555086354930323
# 0.7693442061290536
# Promedio de la combinación: 0.7570662090877303
# Terminé fold
# 0.7509005256579233
# 0.7495975331880326
# 0.7600812776566938
# 0.7555086354930323
# 0.7693442061290536
# Promedio de la combinación: 0.7570864356249472
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.617838916321694
# 0.6134347549699491
# 0.6141891222508421
# 0.6171756323888778
# 0.6197111733042732
# Promedio de la combinación: 0.6164699198471272
# Terminé fold
# 0.617838916321694
# 0.6134347549699491
# 0.6141891222508421
# 0.6171756323888778
# 0.6197111733042732
# Promedio de la combinación: 0.6164699198471272
# Terminé fold
# 0.7730170645454715
# 0.7696083894722937
# 0.7828062050062744
# 0.7796339409550228
# 0.7893395829205468
# Promedio de la combinación: 0.7788810365799219
# Terminé fold
# 0.7730170645454715
# 0.7696083894722937
# 0.7828062050062744
# 0.7796339409550228
# 0.7893395829205468
# Promedio de la combinación: 0.7788810365799219
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.7057841321848682
# 0.7147088204213724
# 0.7189945759857342
# 0.718924402285186
# 0.7146004639719966
# Promedio de la combinación: 0.7146024789698315
# Terminé fold
# 0.7057841321848682
# 0.7147088204213724
# 0.7189945759857342
# 0.718924402285186
# 0.7146004639719966
# Promedio de la combinación: 0.7146024789698315
# Terminé fold
# 0.7770892504656357
# 0.7783346955286969
# 0.7890124496400502
# 0.7834759510600358
# 0.796517939700152
# Promedio de la combinación: 0.7848860572789141
# Terminé fold
# 0.7770892504656357
# 0.7783346955286969
# 0.7890124496400502
# 0.7834759510600358
# 0.796517939700152
# Promedio de la combinación: 0.7848860572789141
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# Promedio de la combinación: 0.5
# Terminé fold
# 0.717195302493085
# 0.7200833003104153
# 0.7296651063337957
# 0.7293152697972394
# 0.7275495756555049
# Promedio de la combinación: 0.7247617109180081
# Terminé fold
# 0.717195302493085
# 0.7200833003104153
# 0.7296651063337957
# 0.7293152697972394
# 0.7275495756555049
# Promedio de la combinación: 0.7247617109180081
# Terminé fold
# 0.7824666861583967
# 0.7832654299583912
# 0.7956387045109306
# 0.7875202265372168
# 0.7987191235717587
# Promedio de la combinación: 0.7895220341473388
# Terminé fold
# 0.7824666861583967
# 0.7832654299583912
# 0.7956387045109306
# 0.7875202265372168
# 0.7987191235717587
# Promedio de la combinación: 0.7895220341473388
# Terminé fold
#    funcion_perdida  estimadores  learning_rate      criterio    rocauc
# 82     exponential          200            0.1  friedman_mse  0.789522
# 83     exponential          200            0.1           mse  0.789522

# %%
parametros_boosting = mejor_combinacion.loc[:].values[0]
boosting = GradientBoostingClassifier(loss = parametros_boosting[0], n_estimators = parametros_boosting[1], learning_rate = parametros_boosting[2])
boosting.fit(X_train,y_train)
y_pred = boosting.predict(X_test)
print(classification_report(y_test, y_pred, target_names=['No Tiene Alto Valor Adquisitivo', 'Tiene Alto Valor Adquisitivo']))
graficar_auc_roc(y_test,y_pred)
# Out:
#                                  precision    recall  f1-score   support
#
# No Tiene Alto Valor Adquisitivo       0.89      0.94      0.92      6159
#    Tiene Alto Valor Adquisitivo       0.78      0.65      0.70      1982
#
#                        accuracy                           0.87      8141
#                       macro avg       0.83      0.79      0.81      8141
#                    weighted avg       0.86      0.87      0.86      8141
# 0.7927789052601846
